# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("fraudTrain.csv")

# %%
df
# Out:
#          Unnamed: 0 trans_date_trans_time               cc_num  \
# 0                 0   2019-01-01 00:00:18     2703186189652095
# 1                 1   2019-01-01 00:00:44         630423337322
# 2                 2   2019-01-01 00:00:51       38859492057661
# 3                 3   2019-01-01 00:01:16     3534093764340240
# 4                 4   2019-01-01 00:03:06      375534208663984
# ...             ...                   ...                  ...
# 1296670     1296670   2020-06-21 12:12:08       30263540414123
# 1296671     1296671   2020-06-21 12:12:19     6011149206456997
# 1296672     1296672   2020-06-21 12:12:32     3514865930894695
# 1296673     1296673   2020-06-21 12:13:36     2720012583106919
# 1296674     1296674   2020-06-21 12:13:37  4292902571056973207
#
#                                     merchant       category     amt  \
# 0                 fraud_Rippin, Kub and Mann       misc_net    4.97
# 1            fraud_Heller, Gutmann and Zieme    grocery_pos  107.23
# ...

# %%
drop_column = ['trans_date_trans_time','merchant','first','last','dob','trans_num','unix_time']
Df = df.drop(columns = drop_column)

# %%
Df.drop(Df.columns[0],axis=1,inplace=True)

# %%
Df
# Out:
#                       cc_num       category     amt gender  \
# 0           2703186189652095       misc_net    4.97      F
# 1               630423337322    grocery_pos  107.23      F
# 2             38859492057661  entertainment  220.11      M
# 3           3534093764340240  gas_transport   45.00      M
# 4            375534208663984       misc_pos   41.96      M
# ...                      ...            ...     ...    ...
# 1296670       30263540414123  entertainment   15.56      M
# 1296671     6011149206456997    food_dining   51.70      M
# 1296672     3514865930894695    food_dining  105.93      M
# 1296673     2720012583106919    food_dining   74.90      M
# 1296674  4292902571056973207    food_dining    4.30      M
#
#                                 street                      city state    zip  \
# 0                       561 Perry Cove            Moravian Falls    NC  28654
# 1         43039 Riley Greens Suite 393                    Orient    WA  99160
# ...

# %%
df_sampled = Df.sample(n=100000, random_state=42)

# %%
df_sampled
# Out:
#                    cc_num        category      amt gender  \
# 1045211      577588686219        misc_pos   194.51      M
# 547406     30376238035123  health_fitness    52.32      F
# 110142   4658490815480264    shopping_pos     6.53      F
# 1285953  3514897282719543            home     7.33      M
# 271705   6011381817520024   gas_transport    64.29      F
# ...                   ...             ...      ...    ...
# 1100175  3529597810116815    shopping_net     4.14      F
# 751678   6538891242532018    shopping_net  1055.18      F
# 813126   3540210836308425       kids_pets    52.96      M
# 367109   4430881574719618   gas_transport    45.15      F
# 1049499    30541100351706     food_dining    27.65      M
#
#                                 street           city state    zip      lat  \
# 1045211             25454 Leonard Lake  Spring Church    PA  15686  40.6153
# 547406              7177 Steven Forges          Sixes    OR  97476  42.8250
# ...

# %%
columns_encode = ['category','gender','street','city','state','job']

# %%
for col in columns_encode:
    print(f"{col} has {df_sampled[col].nunique()} unique values")
# Out:
# category has 14 unique values
# gender has 2 unique values
# street has 948 unique values
# city has 865 unique values
# state has 50 unique values
# job has 482 unique values

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

# %%
df_sampled['category_encoded'] = label_encoder.fit_transform(df_sampled['category'])
df_sampled['gender_encoded'] = label_encoder.fit_transform(df_sampled['gender'])
df_sampled['street_encoded'] = label_encoder.fit_transform(df_sampled['street'])
df_sampled['city_encoded'] = label_encoder.fit_transform(df_sampled['city'])
df_sampled['state_encoded'] = label_encoder.fit_transform(df_sampled['state'])
df_sampled['job_encoded'] = label_encoder.fit_transform(df_sampled['job'])

# %%
drop_column_after_encode = ['category','gender','street','city','state','job']
Df_encoded = df_sampled.drop(columns = drop_column_after_encode)

# %%
Df_encoded
# Out:
#                    cc_num      amt    zip      lat      long  city_pop  \
# 1045211      577588686219   194.51  15686  40.6153  -79.4545       972
# 547406     30376238035123    52.32  97476  42.8250 -124.4409       217
# 110142   4658490815480264     6.53  15449  39.9636  -79.7853       184
# 1285953  3514897282719543     7.33  14425  42.9580  -77.3083     10717
# 271705   6011381817520024    64.29  82221  41.6423 -104.1974       635
# ...                   ...      ...    ...      ...       ...       ...
# 1100175  3529597810116815     4.14  17060  40.4679  -77.8967      1334
# 751678   6538891242532018  1055.18  72476  36.0244  -90.9288      7155
# 813126   3540210836308425    52.96  79085  34.7437 -102.5064        53
# 367109   4430881574719618    45.15  81642  39.3199 -106.6596        61
# 1049499    30541100351706    27.65  77379  30.0377  -95.5326    316665
#
#          merch_lat  merch_long  is_fraud  category_encoded  gender_encoded  \
# ...

# %%
# Df_encoded.to_csv('Corrected_df.csv', index=True)

# %%
x_train = Df_encoded.drop(columns = "is_fraud",axis=1)
y_train = Df_encoded["is_fraud"]

# %%
y_train.value_counts()
# Out:
# is_fraud
# 0    99402
# 1      598
# Name: count, dtype: int64

# %%
# from imblearn.over_sampling import SMOTE
# sm = SMOTE(random_state = 20)
# sm_xtrain,sm_ytrain = sm.fit_resample(x_train,y_train)

# %%
from collections import Counter

print("Before sampling class distribution",Counter(y_train))
print("after sampling class distribution",Counter(sm_ytrain))
# Out:
# Before sampling class distribution Counter({0: 99402, 1: 598})
# after sampling class distribution Counter({0: 99402, 1: 99402})

# %%
# DF = np.column_stack((sm_xtrain,sm_ytrain))
# dataframe = pd.DataFrame(DF)
# dataframe

# %%
# from sklearn.model_selection import train_test_split

# X_train, X_test, Y_train, Y_test = train_test_split(sm_xtrain, sm_ytrain, test_size=0.2)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(x_train, y_train, test_size=0.2)

# %%
X_train
# Out:
#                       cc_num     amt    zip      lat      long  city_pop  \
# 130401   4379260813815979609  181.03  94619  37.7878 -122.1884    381459
# 237301      5540636818935089   66.63   1843  42.6911  -71.1605     76383
# 1117004     4070511711385545    4.79  78113  28.9814  -98.0156      2435
# 584183      4908846471916297   50.04  76050  32.2779  -97.2351      5875
# 767747   4210078554961359092   10.00  97452  43.9210 -122.7806      1420
# ...                      ...     ...    ...      ...       ...       ...
# 885365      3556613125071656   51.01  77566  29.0393  -95.4401     28739
# 266368       346273234529002  186.56  24970  37.7418  -80.4626      4575
# 992787         4561546772499   94.49  87035  34.9889 -106.0609      7268
# 780866   4956828990005111019    9.54   7208  40.6747  -74.2239    124967
# 294200      2248348993063230   21.27  44265  41.0109  -81.2977        51
#
#          merch_lat  merch_long  category_encoded  gender_encoded  \
# ...

# %%
# from sklearn.preprocessing import StandardScaler 
# sc = StandardScaler()
# sc.fit(X_train)
# s_x_train = sc.transform(X_train)
# s_x_test = sc.transform(X_test)

# %%
import scipy.stats as stats
features = Df_encoded.columns[:-1]

for feature in features:
    stat, p = stats.shapiro(Df_encoded[feature])
    print(f'Shapiro-Wilk Test for {feature}: Statistics={stat}, p-value={p}')
# Out:
# Shapiro-Wilk Test for cc_num: Statistics=0.3321090340614319, p-value=0.0
# Shapiro-Wilk Test for amt: Statistics=0.3406830430030823, p-value=0.0
# Shapiro-Wilk Test for zip: Statistics=0.9639859199523926, p-value=0.0
# Shapiro-Wilk Test for lat: Statistics=0.9777892827987671, p-value=0.0
# Shapiro-Wilk Test for long: Statistics=0.9174038767814636, p-value=0.0
# Shapiro-Wilk Test for city_pop: Statistics=0.3158723711967468, p-value=0.0
# Shapiro-Wilk Test for merch_lat: Statistics=0.9799796342849731, p-value=0.0
# Shapiro-Wilk Test for merch_long: Statistics=0.9182892441749573, p-value=0.0
# Shapiro-Wilk Test for is_fraud: Statistics=0.04834544658660889, p-value=0.0
# Shapiro-Wilk Test for category_encoded: Statistics=0.9437875747680664, p-value=0.0
# Shapiro-Wilk Test for gender_encoded: Statistics=0.6337707042694092, p-value=0.0
# Shapiro-Wilk Test for street_encoded: Statistics=0.9585341811180115, p-value=0.0
# ...

# %%
from sklearn.preprocessing import StandardScaler 
sc = StandardScaler()
sc.fit(X_train)
s_x_train = sc.transform(X_train)
s_x_test = sc.transform(X_test)

# %%
s_x_train
# Out:
# array([[ 3.03792411,  0.80600249,  1.70262133, ...,  0.58040347,
#         -1.53807327, -1.49168911],
#        [-0.31347969, -0.02347605, -1.74774081, ..., -0.04301465,
#         -0.54876095, -0.26452293],
#        [-0.31460618, -0.47185851,  1.08875915, ..., -0.71838428,
#          1.14720304, -0.59128316],
#        ...,
#        [-0.31772175,  0.17852808,  1.42057052, ...,  0.32064592,
#          0.36988621,  1.5217663 ],
#        [ 3.4804911 , -0.43741775, -1.54821515, ..., -0.7823246 ,
#          0.29922104,  0.47613358],
#        [-0.31600243, -0.35236719, -0.17005625, ...,  0.88811626,
#          0.58188171,  0.24377075]])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier 
from sklearn.tree import ExtraTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier

from sklearn.metrics import accuracy_score

# %%
# models = {
#     'lg':LogisticRegression(),
#     'gnb':GaussianNB(),
#     'svc':SVC(),
#     'knc':KNeighborsClassifier(),
#     'dtc':DecisionTreeClassifier(),
#     'etc':ExtraTreeClassifier(),
#     'rfc':RandomForestClassifier(),
#     'bc':BaggingClassifier(),
#     'gbc':GradientBoostingClassifier(),
#     'abc':AdaBoostClassifier(),
# }

# for name, md in models.items():
#     md.fit(s_x_train,Y_train)
#     yprep = md.predict(s_x_test)

# print(f"(name) with accurace : {accuracy_score(Y_test,yprep)}")

# %%
# np.random.seed(42)

# # Sample 10000 rows from s_x_train
# sample_indices_x = np.random.choice(s_x_train.shape[0], size=10000, replace=False)
# sample_indices_y = np.random.choice(s_x_train.shape[0], size=10000, replace=False)

# x_train_2 = s_x_train[sample_indices]

# %% [markdown]
# ## Logistic Rregreesion

# %%
model = LogisticRegression()
model.fit(s_x_train,Y_train)
# Out:
# LogisticRegression()

# %%
s_x_train_prediction = model.predict(s_x_train)#it is the prediction with input xtrain
train_data_accuracy = accuracy_score(Y_train,s_x_train_prediction)
print(f"train_data accuracy by logistic is : {train_data_accuracy}")
s_x_test_prediction = model.predict(s_x_test)#it is the prediction with input xtrain
test_data_accuracy = accuracy_score(Y_test,s_x_test_prediction)
print(f"test_data accuracy by logistic is : {test_data_accuracy}")
# Out:
# train_data accuracy by logistic is : 0.993075
# test_data accuracy by logistic is : 0.99345

# %% [markdown]
# ## prediction with LogisticRegression based model

# %%
input_data = (213124978348176,15.95,14711,42.32,-78.0943,1766,41.41192,-78.747801,3,1,70,60,33,279)

nump = np.asarray(input_data)
#reshape the numpy array as we are predicting for one datapoint
reshape_data = nump.reshape(1,-1)
prediction_1 = model.predict(reshape_data)
print(prediction_1)
# Out:
# [0]

# %% [markdown]
# ## Random Forest

# %%
model_2 = RandomForestClassifier()
model_2.fit(s_x_train,Y_train)
# Out:
# RandomForestClassifier()

# %%
s_x_train_prediction_r = model_2.predict(s_x_train)#it is the prediction with input xtrain
train_data_accuracy_r = accuracy_score(Y_train,s_x_train_prediction_r)
print(f"train_data accuracy by random forest is : {train_data_accuracy_r}")

s_x_test_prediction_r = model_2.predict(s_x_test)#it is the prediction with input xtrain
test_data_accuracy_r = accuracy_score(Y_test,s_x_test_prediction_r)
print(f"test_data accuracy by random forest is : {test_data_accuracy_r}")
# Out:
# train_data accuracy by random forest is : 1.0
# test_data accuracy by random forest is : 0.99625

# %% [markdown]
# ## prediction with RandomForest based model

# %%
input_data = (213124978348176,15.95,14711,42.32,-78.0943,1766,41.41192,-78.747801,3,1,70,60,33,279)

nump = np.asarray(input_data)
#reshape the numpy array as we are predicting for one datapoint
reshape_data = nump.reshape(1,-1)
prediction_2 = model_2.predict(reshape_data)
print(prediction_2)
# Out:
# [0]

# %% [markdown]
# ## Decision Tree

# %%
model_3 = DecisionTreeClassifier()
model_3.fit(s_x_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
s_x_train_prediction_d = model_3.predict(s_x_train)#it is the prediction with input xtrain
train_data_accuracy_d = accuracy_score(Y_train,s_x_train_prediction_d)
print(f"train_data accuracy by decision tree is : {train_data_accuracy_d}")

s_x_test_prediction_d = model_3.predict(s_x_test)#it is the prediction with input xtrain
test_data_accuracy_d = accuracy_score(Y_test,s_x_test_prediction_d)
print(f"test_data accuracy by decision tree is : {test_data_accuracy_d}")
# Out:
# train_data accuracy by decision tree is : 1.0
# test_data accuracy by decision tree is : 0.9948

# %% [markdown]
# ## prediction with DecisionTree based model

# %%
input_data = (213124978348176,15.95,14711,42.32,-78.0943,1766,41.41192,-78.747801,3,1,70,60,33,279)

nump = np.asarray(input_data)
#reshape the numpy array as we are predicting for one datapoint
reshape_data = nump.reshape(1,-1)
prediction_3 = model_3.predict(reshape_data)
print(prediction_3)
# Out:
# [0]

# %% [markdown]
# ## Gradient Boosting

# %%
model_4 = GradientBoostingClassifier()
model_4.fit(s_x_train,Y_train)
# Out:
# GradientBoostingClassifier()

# %%
s_x_train_prediction_G = model_4.predict(s_x_train)#it is the prediction with input xtrain
train_data_accuracy_G = accuracy_score(Y_train,s_x_train_prediction_G)
print(f"train_data accuracy by Gradient Boosting is : {train_data_accuracy_G}")

s_x_test_prediction_G = model_4.predict(s_x_test)#it is the prediction with input xtrain
test_data_accuracy_G = accuracy_score(Y_test,s_x_test_prediction_G)
print(f"test_data accuracy by Gradient Boosting is : {test_data_accuracy_G}")
# Out:
# train_data accuracy by Gradient Boosting is : 0.998075
# test_data accuracy by Gradient Boosting is : 0.99615

# %% [markdown]
# ## prediction with GradientBoosting

# %%
input_data = (213124978348176,15.95,14711,42.32,-78.0943,1766,41.41192,-78.747801,3,1,70,60,33,279)

nump = np.asarray(input_data)
#reshape the numpy array as we are predicting for one datapoint
reshape_data = nump.reshape(1,-1)
prediction_4 = model_4.predict(reshape_data)
print(prediction_4)
# Out:
# [0]
